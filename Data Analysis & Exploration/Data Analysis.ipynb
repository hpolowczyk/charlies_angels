# %%
#Load dependenices
import pandas as pd

# %%
import pymongo

# MongoDB connection
conn = 'mongodb+srv://general_user:charli3s_ang3ls@cluster0-tyboh.mongodb.net/movie_db?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# Declare the collection
collection = client.movie_db.movie_reviews.find()

# %%
# Load Data into DF
new_df = pd.DataFrame( collection)
new_df.head()
# Out:
#                                               Actors  \
# 0  Lavinia Wilson, Barnaby Metschurat, Matthias K...
# 1  Tôru Furuya, Mami Koyama, Keiko Han, Michiko N...
# 2  Lars Hanson, Marceline Day, Pauline Starke, Er...
# 3  Toni Collette, Parker Posey, Lisa Kudrow, Alan...
# 4  William Boyd, Mary Astor, Louis Wolheim, Ian K...
#
#                                         Genre  \
# 0                              Drama, Romance
# 1  Animation, Drama, Family, Fantasy, Romance
# 2                              Drama, Romance
# 3                               Comedy, Drama
# 4                  Comedy, Romance, Adventure
#
#                                               Parsed  \
# 0  [spoilers, spoilers, basis, movie, classic, no...
# 1  [rare, event, rate, movie, level, 10, could, w...
# 2  [first, half, twothirds, film, worked, well, w...
# 3  [thing, think, reading, negative, comments, le...
# 4  [finally, broadcast, turner, classic, movies, ...
#
#                                                 Plot  \
# 0                                                N/A
# 1  Years after the war between the Children of Wa...
# 2  A returning seminary student goes up against a...
# 3  Iris can best be described as a wallflower. Sh...
# 4  Americans Sgt. Peter O'Gaffney and one of his ...
#
#                                               Poster Review_Type  \
# 0  https://m.media-amazon.com/images/M/MV5BMGJhOD...    positive
# 1  https://m.media-amazon.com/images/M/MV5BZGJmND...    positive
# 2  https://m.media-amazon.com/images/M/MV5BMTc3OT...    positive
# 3  https://m.media-amazon.com/images/M/MV5BYzZlND...    positive
# 4  https://m.media-amazon.com/images/M/MV5BNTJiNG...    positive
#
#                            Title  Year                       _id  label_orig  \
# 0                       Julietta  2001  5dd24aeaa6edc0dcb0d75569         6.2
# 1  Sea Prince and the Fire Child  1981  5dd24aeaa6edc0dcb0d75566         7.2
# 2              Captain Salvation  1927  5dd24aeaa6edc0dcb0d75568         6.9
# 3                  Clockwatchers  1997  5dd24aeaa6edc0dcb0d75563         6.5
# 4            Two Arabian Knights  1927  5dd24aeaa6edc0dcb0d75562         6.9
#
#     movie_id                                            reviews  \
# 0  tt0248123  ***SPOILERS***   ***SPOILERS*** The basis to t...
# 1  tt0203895  It is a rare event when I rate a movie on the ...
# 2  tt0017735  The first half to two-thirds of the film worke...
# 3  tt0118866  The only thing that I can think when reading t...
# 4  tt0018515  Finally broadcast by Turner Classic Movies on ...
#
#                                            url
# 0  http://www.imdb.com/title/tt0248123/reviews
# 1  http://www.imdb.com/title/tt0203895/reviews
# 2  http://www.imdb.com/title/tt0017735/reviews
# 3  http://www.imdb.com/title/tt0118866/reviews
# 4  http://www.imdb.com/title/tt0018515/reviews

# %%
# Describe columns
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5972 entries, 0 to 5971
# Data columns (total 13 columns):
# Actors         5972 non-null object
# Genre          5972 non-null object
# Parsed         5972 non-null object
# Plot           5972 non-null object
# Poster         5972 non-null object
# Review_Type    5972 non-null object
# Title          5972 non-null object
# Year           5972 non-null int64
# _id            5972 non-null object
# label_orig     5972 non-null float64
# movie_id       5972 non-null object
# reviews        5972 non-null object
# url            5972 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 606.6+ KB

# %%
# Change Parsed to string
new_df['Parsed'] = new_df['Parsed'].astype(str)
new_df.head()
# Out:
#                                               Actors  \
# 0  Lavinia Wilson, Barnaby Metschurat, Matthias K...
# 1  Tôru Furuya, Mami Koyama, Keiko Han, Michiko N...
# 2  Lars Hanson, Marceline Day, Pauline Starke, Er...
# 3  Toni Collette, Parker Posey, Lisa Kudrow, Alan...
# 4  William Boyd, Mary Astor, Louis Wolheim, Ian K...
#
#                                         Genre  \
# 0                              Drama, Romance
# 1  Animation, Drama, Family, Fantasy, Romance
# 2                              Drama, Romance
# 3                               Comedy, Drama
# 4                  Comedy, Romance, Adventure
#
#                                               Parsed  \
# 0  ['spoilers', 'spoilers', 'basis', 'movie', 'cl...
# 1  ['rare', 'event', 'rate', 'movie', 'level', '1...
# 2  ['first', 'half', 'twothirds', 'film', 'worked...
# 3  ['thing', 'think', 'reading', 'negative', 'com...
# 4  ['finally', 'broadcast', 'turner', 'classic', ...
#
#                                                 Plot  \
# 0                                                N/A
# 1  Years after the war between the Children of Wa...
# 2  A returning seminary student goes up against a...
# 3  Iris can best be described as a wallflower. Sh...
# 4  Americans Sgt. Peter O'Gaffney and one of his ...
#
#                                               Poster Review_Type  \
# 0  https://m.media-amazon.com/images/M/MV5BMGJhOD...    positive
# 1  https://m.media-amazon.com/images/M/MV5BZGJmND...    positive
# 2  https://m.media-amazon.com/images/M/MV5BMTc3OT...    positive
# 3  https://m.media-amazon.com/images/M/MV5BYzZlND...    positive
# 4  https://m.media-amazon.com/images/M/MV5BNTJiNG...    positive
#
#                            Title  Year                       _id  label_orig  \
# 0                       Julietta  2001  5dd24aeaa6edc0dcb0d75569         6.2
# 1  Sea Prince and the Fire Child  1981  5dd24aeaa6edc0dcb0d75566         7.2
# 2              Captain Salvation  1927  5dd24aeaa6edc0dcb0d75568         6.9
# 3                  Clockwatchers  1997  5dd24aeaa6edc0dcb0d75563         6.5
# 4            Two Arabian Knights  1927  5dd24aeaa6edc0dcb0d75562         6.9
#
#     movie_id                                            reviews  \
# 0  tt0248123  ***SPOILERS***   ***SPOILERS*** The basis to t...
# 1  tt0203895  It is a rare event when I rate a movie on the ...
# 2  tt0017735  The first half to two-thirds of the film worke...
# 3  tt0118866  The only thing that I can think when reading t...
# 4  tt0018515  Finally broadcast by Turner Classic Movies on ...
#
#                                            url
# 0  http://www.imdb.com/title/tt0248123/reviews
# 1  http://www.imdb.com/title/tt0203895/reviews
# 2  http://www.imdb.com/title/tt0017735/reviews
# 3  http://www.imdb.com/title/tt0118866/reviews
# 4  http://www.imdb.com/title/tt0018515/reviews

# %%
# Renamed Column
new_df = new_df.rename(columns={'label_orig': 'IMDB_Ratings'})

# %%
# Copy df
copynew = new_df.copy()

# %%
# Gather and separate samples of the reviews into postive and negative
positive_reviews = copynew.loc[copynew['Review_Type'] == 'positive']
positive_reviews = positive_reviews.sample(1000)
positive_reviews = positive_reviews.reset_index(drop=True)
negative_reviews = copynew.loc[copynew['Review_Type'] == 'negative']
negative_reviews = negative_reviews.sample(1000)
negative_reviews = negative_reviews.reset_index(drop=True)

# %%
# Join texts
positive_text = " ".join(review for review in positive_reviews.Parsed)
negative_text = " ".join(review for review in negative_reviews.Parsed)

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# WordCloud for Positive Reviews
wordcloud = WordCloud(width=500, height=500, max_font_size=40, min_font_size=15).generate(positive_text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
wordcloud.to_file("Positive_Reviews.png")

# %%
# WordCloud for Negative Reviews
wordcloud = WordCloud(width=500, height=500, max_font_size=40, min_font_size=15).generate(negative_text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
# plt.show()
wordcloud.to_file("Negative_Reviews.png")

# %%
# import matplotlib
import matplotlib.pyplot as plt
# import seaborn
import seaborn as sns
# %matplotlib inline

# %%
# Boxplot
bplot = sns.boxplot(y='IMDB_Ratings', x='Review_Type', 
                 data=copynew, 
                 width=0.5,
                 palette="colorblind")

# output file name
plot_file_name="boxplot.jpg"
 
# save as jpeg
bplot.figure.savefig(plot_file_name,
                    format='jpeg',
                    dpi=100)

# %%
# Scatterplot
splot = sns.scatterplot(x="IMDB_Ratings", y="Year", data=copynew)

# output file name
scatterplot="scatterplot.jpg"
 
# save as jpeg
splot.figure.savefig(scatterplot,
                    format='jpeg',
                    dpi=100)

# %%
print(type(positive_text[0:100]))
# Out:
# <class 'str'>

# %%
# Change string to list
positive_text_split = str.split(positive_text)
print(type(positive_text_split))
# Out:
# <class 'list'>

# %%
negative_text_split = str.split(negative_text)
print(type(negative_text_split))
# Out:
# <class 'list'>

# %%
# FreqDist of text
from nltk.probability import FreqDist
fdist = FreqDist(positive_text_split)
print(fdist)
# Out:
# <FreqDist with 127518 samples and 2611486 outcomes>

# %%
# Positive_Word_Count Chart
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()
plt.savefig('Positive_Word_Count.png')

# %%
# FreqDist of text
from nltk.probability import FreqDist
fdist = FreqDist(negative_text_split)
print(fdist)
# Out:
# <FreqDist with 107555 samples and 2005445 outcomes>

# %%
# Negative_Word_Count Chart
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()
plt.savefig('Negative_Word_Count.png')

# %%
negative_text_split
# Out:
# ["['yeah',",
#  "'yeahwho',",
#  "'could',",
#  "'find',",
#  "'fault',",
#  "'implausible',",
#  "'menagerie',",
#  "'models',",
#  "'marxists',",
#  "'even',",
#  "'inept',",
#  "'filmschoolers',",
#  "'could',",
#  "'find',",
#  "'surplus',",
#  "'shortfalls',",
#  "'offer',",
#  "'trite',",
#  "'insight',",
#  "'whats',",
#  "'blatantly',",
#  "'apparent',",
#  "'film',",
#  "'isthe',",
#  "'script',",
#  "'seems',",
#  "'never',",
#  "'transcended',",
#  "'firstdraft',",
#  "'stagethe',",
#  "'characters',",
#  "'seem',",
#  "'either',",
#  "'psychotropic',",
#  "'drugs',",
#  "'need',",
#  "'psychotherapeutic',",
#  "'onesand',",
#  "'director',",
#  "'seems',",
#  "'mind',",
#  "'things',",
#  "'\\x96',",
#  "'perhaps',",
#  "'act',",
#  "'small',",
#  "'completely',",
#  "'forgettable',",
#  "'parthowever',",
#  "'us',",
#  "'challenge',",
#  "'discover',",
#  "'good',",
#  "'points',",
#  "'critical',",
#  "'failures',",
#  "'exposed',",
#  "'everyone',",
#  "'seems',",
#  "'somewhat',",
#  "'vaguely',",
#  "'aware',",
#  "'whats',",
#  "'redeeming',",
#  "'film',",
#  "'word',",
#  "'nastassjakinski',",
#  "'camera',",
#  "'problems',",
#  "'behind',",
#  "'seem',",
#  "'insignificantcheers',",
#  "'jb',",
#  "'prospect',",
#  "'point',",
#  "'productions',",
#  "'inc',",
#  "'early',",
#  "'80s',",
#  "'seemed',",
#  "'ripe',",
#  "'time',",
#  "'espionagethemed',",
#  "'films',",
#  "'taken',",
#  "'whole',",
#  "'probably',",
#  "'somewhere',",
#  "'middle',",
#  "'terms',",
#  "'quality',",
#  "'goodness',",
#  "'knows',",
#  "'worse',",
#  "'however',",
#  "'makes',",
#  "'worth',",
#  "'seeing',",
#  "'two',",
#  "'things',",
#  "'european',",
#  "'locales',",
#  "'monochromatic',",
#  "'greys',",
#  "'browns',",
#  "'first',",
#  "'foremost',",
#  "'astonishing',",
#  "'eyeachingly',",
#  "'beautiful',",
#  "'kinski',",
#  "'may',",
#  "'well',",
#  "'ripest',",
#  "'fiercest',",
#  "'raw',",
#  "'performance',",
#  "'captured',",
#  "'film',",
#  "'surrounds',",
#  "'unfortunately',",
#  "'either',",
#  "'standard',",
#  "'downright',",
#  "'embarassing',",
#  "'wooden',",
#  "'supporting',",
#  "'performances',",
#  "'particularly',",
#  "'nureyev',",
#  "'looks',",
#  "'singularly',",
#  "'uneasy',",
#  "'clodding',",
#  "'ironic',",
#  "'someone',",
#  "'spent',",
#  "'lifetime',",
#  "'praised',",
#  "'graceful',",
#  "'moves',",
#  "'often',",
#  "'senseless',",
#  "'plot',",
#  "'direction',",
#  "'veers',",
#  "'shameful',",
#  "'confused',",
#  "'none',",
#  "'helped',",
#  "'sometimesspastic',",
#  "'editing',",
#  "'yetthere',",
#  "'kinski',",
#  "'breathing',",
#  "'life',",
#  "'dull',",
#  "'affair',",
#  "'spite',",
#  "'wiping',",
#  "'everyone',",
#  "'else',",
#  "'screen',",
#  "'audiences',",
#  "'eyes',",
#  "'minds',",
#  "'force',",
#  "'reckoned',",
#  "'radiating',",
#  "'intriguing',",
#  "'blend',",
#  "'natural',",
#  "'awkwardness',",
#  "'justenough',",
#  "'confidence',",
#  "'essence',",
#  "'100',",
#  "'real',",
#  "'isnt',",
#  "'single',",
#  "'false',",
#  "'moment',",
#  "'delivered',",
#  "'young',",
#  "'woman',",
#  "'falls',",
#  "'world',",
#  "'modeling',",
#  "'espionage',",
#  "'giving',",
#  "'film',",
#  "'whole',",
#  "'unmistakable',",
#  "'air',",
#  "'whatcouldhavebeen',",
#  "'movie',",
#  "'tenth',",
#  "'provides',",
#  "'would',",
#  "'still',",
#  "'rate',",
#  "'despite',",
#  "'dated',",
#  "'modernday',",
#  "'classic',",
#  "'whatever',",
#  "'many',",
#  "'many',",
#  "'flaws',",
#  "'worth',",
#  "'seeing',",
#  "'oftensilly',",
#  "'early80s',",
#  "'fashions',",
#  "'time',",
#  "'machine',",
#  "'aforementioned',",
#  "'locales',",
#  "'main',",
#  "'reason',",
#  "'brilliant',",
#  "'moments',",
#  "'film',",
#  "'amazing',",
#  "'hard',",
#  "'describe',",
#  "'words',",
#  "'occurs',",
#  "'film',",
#  "'find',",
#  "'strikingkinski',",
#  "'sheer',",
#  "'brilliance',",
#  "'delivers',",
#  "'phenomenal',",
#  "'performance',",
#  "'seduces',",
#  "'camera',",
#  "'without',",
#  "'ego',",
#  "'never',",
#  "'seen',",
#  "'done',",
#  "'another',",
#  "'actress',",
#  "'sense',",
#  "'though',",
#  "'watching',",
#  "'documentarythe',",
#  "'film',",
#  "'awful',",
#  "'mess',",
#  "'time',",
#  "'found',",
#  "'fascinating',",
#  "'dance',",
#  "'kinski',",
#  "'unfurnished',",
#  "'apartment',",
#  "'strong',",
#  "'sense',",
#  "'individual',",
#  "'void',",
#  "'conformity',",
#  "'life',",
#  "'dances',",
#  "'beat',",
#  "'drumthere',",
#  "'another',",
#  "'scene',",
#  "'kinski',",
#  "'gets',",
#  "'cab',",
#  "'falls',",
#  "'street',",
#  "'gets',",
#  "'runs',",
#  "'away',",
#  "'limp',",
#  "'step',",
#  "'found',",
#  "'intriguing',",
#  "'say',",
#  "'seemed',",
#  "'awkward',",
#  "'awkward',",
#  "'filmi',",
#  "'like',",
#  "'foolishness',",
#  "'attempt',",
#  "'making',",
#  "'world',",
#  "'fashion',",
#  "'terrorism',",
#  "'seem',",
#  "'romantickinski',",
#  "'breaks',",
#  "'barrier',",
#  "'audience',",
#  "'screen',",
#  "'magazine',",
#  "'variety',",
#  "'stated',",
#  "'perfect',",
#  "'description',",
#  "'performance',",
#  "'roger',",
#  "'ebert',",
#  "'offers',",
#  "'excellent',",
#  "'review',",
#  "'film',",
#  "'highly',",
#  "'agree',",
#  "'itcheck',",
#  "'sometime',",
#  "'see',",
#  "'star',",
#  "'work',",
#  "'like',",
#  "'others',",
#  "'commented',",
#  "'film',",
#  "'first',",
#  "'watched',",
#  "'20',",
#  "'years',",
#  "'ago',",
#  "'seen',",
#  "'times',",
#  "'since',",
#  "'im',",
#  "'sure',",
#  "'definitely',",
#  "'intriguing',",
#  "'mess',",
#  "'story',",
#  "'wisconsin',",
#  "'girl',",
#  "'named',",
#  "'elizabeth',",
#  "'carlson',",
#  "'nastassja',",
#  "'kinski',",
#  "'leaves',",
#  "'college',",
#  "'heads',",
#  "'new',",
#  "'york',",
#  "'city',",
#  "'getting',",
#  "'job',",
#  "'waitress',",
#  "'discovered',",
#  "'fashion',",
#  "'agent',",
#  "'makes',",
#  "'successful',",
#  "'modelspoiler',",
#  "'alert',",
#  "'going',",
#  "'notices',",
#  "'strange',",
#  "'man',",
#  "'following',",
#  "'rudolf',",
#  "'nureyev',",
#  "'eventually',",
#  "'confront',",
#  "'learns',",
#  "'name',",
#  "'daniel',",
#  "'jelline',",
#  "'wants',",
#  "'kill',",
#  "'terrorist',",
#  "'engage',",
#  "'romance',",
#  "'follows',",
#  "'paris',",
#  "'gets',",
#  "'upset',",
#  "'discovers',",
#  "'used',",
#  "'try',",
#  "'get',",
#  "'closer',",
#  "'rivas',",
#  "'harvey',",
#  "'keitel',",
#  "'whos',",
#  "'terrorist',",
#  "'plotting',",
#  "'next',",
#  "'act',",
#  "'destruction',",
#  "'elizabeth',",
#  "'notices',",
#  "'woman',",
#  "'new',",
#  "'york',",
#  "'watching',",
#  "'recognizes',",
#  "'one',",
#  "'members',",
#  "'rivas',",
#  "'gang',",
#  "'strike',",
#  "'conversation',",
#  "'results',",
#  "'getting',",
#  "'opportunity',",
#  "'meet',",
#  "'rivas',",
#  "'lets',",
#  "'go',",
#  "'immediately',",
#  "'goes',",
#  "'get',",
#  "'daniel',",
#  "'leads',",
#  "'violent',",
#  "'bloody',",
#  "'conclusionthis',",
#  "'third',",
#  "'film',",
#  "'james',",
#  "'toback',",
#  "'written',",
#  "'directed',",
#  "'still',",
#  "'riding',",
#  "'critical',",
#  "'praise',",
#  "'first',",
#  "'film',",
#  "'fingers',",
#  "'seemed',",
#  "'bite',",
#  "'could',",
#  "'chew',",
#  "'story',",
#  "'first',",
#  "'nobody',",
#  "'believed',",
#  "'kinski',",
#  "'girl',",
#  "'midwest',",
#  "'never',",
#  "'appeared',",
#  "'home',",
#  "'arrived',",
#  "'paris',",
#  "'keitel',",
#  "'woefully',",
#  "'miscast',",
#  "'terrorist',",
#  "'multiple',",
#  "'viewings',",
#  "'film',",
#  "'never',",
#  "'sure',",
#  "'supposed',",
#  "'parisian',",
#  "'something',",
#  "'else',",
#  "'ive',",
#  "'heard',",
#  "'everyone',",
#  "'describe',",
#  "'nureyevs',",
#  "'performance',",
#  "'wooden',",
#  "'stiff',",
#  "'dark',",
#  "'eyes',",
#  "'always',",
#  "'compared',",
#  "'dracula',",
#  "'every',",
#  "'time',",
#  "'spoke',",
#  "'would',",
#  "'either',",
#  "'speak',",
#  "'metaphors',",
#  "'recite',",
#  "'something',",
#  "'poetically',",
#  "'film',",
#  "'always',",
#  "'something',",
#  "'curiosity',",
#  "'reason',",
#  "'get',",
#  "'admit',",
#  "'bad',",
#  "'film',",
#  "'theres',",
#  "'something',",
#  "'alluring',",
#  "'intriguing',",
#  "'story',",
#  "'think',",
#  "'casting',",
#  "'kinski',",
#  "'often',",
#  "'described',",
#  "'force',",
#  "'reckon',",
#  "'one',",
#  "'point',",
#  "'kinski',",
#  "'dance',",
#  "'unique',",
#  "'screen',",
#  "'presence',",
#  "'one',",
#  "'cant',",
#  "'help',",
#  "'absorbed',",
#  "'character',",
#  "'tobacks',",
#  "'script',",
#  "'film',",
#  "'high',",
#  "'aspirations',",
#  "'ambitious',",
#  "'us',",
#  "'commands',",
#  "'sort',",
#  "'attention',",
#  "'many',",
#  "'future',",
#  "'viewers',",
#  "'simply',",
#  "'reject',",
#  "'one',",
#  "'viewing',",
#  "'think',",
#  "'twice',",
#  "'us',",
#  "'watched',",
#  "'kinski',",
#  "'toback',",
#  "'rise',",
#  "'theyre',",
#  "'abilities',",
#  "'early',",
#  "'80s',",
#  "'clumsy',",
#  "'film',",
#  "'always',",
#  "'something',",
#  "'curiosity',",
#  "'exposed',",
#  "'one',",
#  "'unusual',",
#  "'different',",
#  "'unpredictable',",
#  "'films',",
#  "'ever',",
#  "'seen',",
#  "'many',",
#  "'reviews',",
#  "'imdb',",
#  "'fault',",
#  "'film',",
#  "'incoherent',",
#  "'plot',",
#  "'actually',",
#  "'believe',",
#  "'criticism',",
#  "'unjustified',",
#  "'since',",
#  "'writerdirector',",
#  "'james',",
#  "'toback',",
#  "'really',",
#  "'trying',",
#  "'make',",
#  "'ambitious',",
#  "'film',",
#  "'theme',",
#  "'western',",
#  "'world',",
#  "'breaking',",
#  "'morally',",
#  "'politically',",
#  "'economically',",
#  "'every',",
#  "'way',",
#  "'toback',",
#  "'playing',",
#  "'professor',",
#  "'picture',",
#  "'even',",
#  "'makes',",
#  "'point',",
#  "'rather',",
#  "'banally',",
#  "'classroom',",
#  "'filled',",
#  "'indifferent',",
#  "'students',",
#  "'film',",
#  "'pursues',",
#  "'theme',",
#  "'fresh',",
#  "'original',",
#  "'way',",
#  "'exploring',",
#  "'turbulent',",
#  "'life',",
#  "'elizabeth',",
#  "'carlson',",
#  "'played',",
#  "'brilliantly',",
#  "'german',",
#  "'actress',",
#  "'nastassja',",
#  "'kinski',",
#  "'beginning',",
#  "'film',",
#  "'shows',",
#  "'terrorist',",
#  "'attack',",
#  "'elizabeth',",
#  "'looking',",
#  "'indifferently',",
#  "'literature',",
#  "'professor',",
#  "'order',",
#  "'begging',",
#  "'question',",
#  "'two',",
#  "'scenes',",
#  "'related',",
#  "'course',",
#  "'series',",
#  "'extraordinary',",
#  "'nonetheless',",
#  "'plausible',",
#  "'plot',",
#  "'twists',",
#  "'learn',",
#  "'answer',",
#  "'question',",
#  "'end',",
#  "'film',",
#  "'shows',",
#  "'elizabeth',",
#  "'gazing',",
#  "'dying',",
#  "'lover',",
#  "'streets',",
#  "'paris',",
#  "'western',",
#  "'world',",
#  "'metaphorical',",
#  "'sense',",
#  "'collapses',",
#  "'around',",
#  "'heraside',",
#  "'mostly',",
#  "'interesting',",
#  "'plot',",
#  "'strength',",
#  "'film',",
#  "'lies',",
#  "'natassija',",
#  "'kinskis',",
#  "'performance',",
#  "'elizabeth',",
#  "'plays',",
#  "'character',",
#  "'brilliantly',",
#  "'almost',",
#  "'overlook',",
#  "'moments',",
#  "'film',",
#  "'delivers',",
#  "'poor',",
#  "'lines',",
#  "'rudolf',",
#  "'nureyevs',",
#  "'performance',",
#  "'enigmatic',",
#  "'violinist',",
#  "'david',",
#  "'jelline',",
#  "'good',",
#  "'still',",
#  "'interesting',",
#  "'watch',",
#  "'film',",
#  "'without',",
#  "'weaknesses',",
#  "'found',",
#  "'acting',",
#  "'supporting',",
#  "'cast',",
#  "'amateurish',",
#  "'dull',",
#  "'including',",
#  "'tobacks',",
#  "'brief',",
#  "'performance',",
#  "'literature',",
#  "'professor',",
#  "'moreover',",
#  "'exposed',",
#  "'starts',",
#  "'bit',",
#  "'slowly',",
#  "'beginning',",
#  "'picking',",
#  "'tempo',",
#  "'becoming',",
#  "'interesting',",
#  "'yet',",
#  "'enough',",
#  "'unexpected',",
#  "'plot',",
#  "'developments',",
#  "'including',",
#  "'violin',",
#  "'seduction',",
#  "'seen',",
#  "'believed',",
#  "'classical',",
#  "'music',",
#  "'interesting',",
#  "'characters',",
#  "'keep',",
#  "'interested',",
#  "'right',",
#  "'end',",
#  "'exposed',",
#  "'one',",
#  "'stories',",
#  "'take',",
#  "'quite',",
#  "'long',",
#  "'time',",
#  "'finally',",
#  "'get',",
#  "'needs',",
#  "'makes',",
#  "'turns',",
#  "'twists',",
#  "'gets',",
#  "'point',",
#  "'rushes',",
#  "'things',",
#  "'shouldnt',",
#  "'develops',",
#  "'much',",
#  "'one',",
#  "'character',",
#  "'hides',",
#  "'much',",
#  "'presenting',",
#  "'others',",
#  "'viewed',",
#  "'strange',",
#  "'difficulting',",
#  "'accepting',",
#  "'everything',",
#  "'presented',",
#  "'follow',",
#  "'detail',",
#  "'stardom',",
#  "'elizabeth',",
#  "'nastassja',",
#  "'kinski',",
#  "'young',",
#  "'woman',",
#  "'abandons',",
#  "'studies',",
#  "'goes',",
#  "'new',",
#  "'york',",
#  "'try',",
#  "'make',",
#  "'living',",
#  "'fails',",
#  "'gets',",
#  "'discovered',",
#  "'photographer',",
#  "'ian',",
#  "'mcshane',",
#  "'wholl',",
#  "'make',",
#  "'supermodel',",
#  "'like',",
#  "'barely',",
#  "'girl',",
#  "'could',",
#  "'predict',",
#  "'going',",
#  "'meet',",
#  "'strange',",
#  "'man',",
#  "'rudolf',",
#  "'nureyev',",
#  "'would',",
#  "'make',",
#  "'life',",
#  "'turn',",
#  "'upside',",
#  "'offer',",
#  "'help',",
#  "'catch',",
#  "'terrorist',",
#  "'harvey',",
#  "'keitel',",
#  "'group',",
#  "'spreads',",
#  "'terror',",
#  "'europe',",
#  "'connection',",
#  "'isnt',",
#  "'worth',",
#  "'mentioning',",
#  "'one',",
#  "'say',",
#  "'doesnt',",
#  "'satisfy',",
#  "'much',",
#  "'theres',",
#  "'something',",
#  "'missing',",
#  "'clear',",
#  "'elizabeth',",
#  "'joining',",
#  "'man',",
#  "'would',",
#  "'benefit',",
#  "'way',",
#  "'probably',",
#  "'shes',",
#  "'share',",
#  "'something',",
#  "'special',",
#  "'put',",
#  "'aside',",
#  "'logic',",
#  "'great',",
#  "'notion',",
#  "'makes',",
#  "'great',",
#  "'movies',",
#  "'great',",
#  "'exposed',",
#  "'one',",
#  "'thing',",
#  "'fun',",
#  "'watch',",
#  "'glamorous',",
#  "'exciting',",
#  "'little',",
#  "'thrilling',",
#  "'multigenre',",
#  "'piece',",
#  "'knows',",
#  "'sell',",
#  "'beauty',",
#  "'pleasure',",
#  "'joys',",
#  "'highlife',",
#  "'excitement',",
#  "'fashion',",
#  "'world',",
#  "'rare',",
#  "'seen',",
#  "'movies',",
#  "'life',",
#  "'throws',",
#  "'middle',",
#  "'strange',",
#  "'view',",
#  "'current',",
#  "'wave',",
#  "'terrorism',",
#  "'1980s',",
#  "'idealists',",
#  "'fighting',",
#  "'imperialism',",
#  "'yet',",
#  "'part',",
#  "'wanting',",
#  "'things',",
#  "'keitels',",
#  "'character',",
#  "'makes',",
#  "'perfectly',",
#  "'clear',",
#  "'things',",
#  "'fights',",
#  "'got',",
#  "'ta',",
#  "'acknowledge',",
#  "'way',",
#  "'director',",
#  "'james',",
#  "'toback',",
#  "'films',",
#  "'presents',",
#  "'whole',",
#  "'thing',",
#  "'great',",
#  "'sense',",
#  "'style',",
#  "'scenes',",
#  "'paris',",
#  "'fascinating',",
#  "'ones',",
#  "'new',",
#  "'york',",
#  "'much',",
#  "'sensual',",
#  "'provocative',",
#  "'theres',",
#  "'even',",
#  "'bits',",
#  "'good',",
#  "'dialogues',",
#  "'high',",
#  "'points',",
#  "'opening',",
#  "'scene',",
#  "'ending',",
#  "'terrorist',",
#  "'attack',",
#  "'heart',",
#  "'goes',",
#  "'mouth',",
#  "'part',",
#  "'violin',",
#  "'scene',",
#  "'one',",
#  "'erotic',",
#  "'moments',",
#  "'film',",
#  "'history',",
#  "'clothes',",
#  "'elizabeth',",
#  "'joining',",
#  "'group',",
#  "'ending',",
#  "'rushed',",
#  "'could',",
#  "'inventive',",
#  "'riskier',",
#  "'dangerous',",
#  "'happened',",
#  "'bombsmost',",
#  "'reviews',",
#  "'states',",
#  "'exposed',",
#  "'mess',",
#  "'wonder',",
#  "'people',",
#  "'really',",
#  "'watching',",
#  "'movie',",
#  "'maybe',",
#  "'dazzled',",
#  "'kinskis',",
#  "'beauty',",
#  "'got',",
#  "'lost',",
#  "'somewhere',",
#  "'couldnt',",
#  "'keep',",
#  "'going',",
#  "'right',",
#  "'story',",
#  "'messy',",
#  "'quite',",
#  "'simple',",
#  "'follow',",
#  "'upsets',",
#  "'giant',",
#  "'plot',",
#  "'hole',",
#  "'featured',",
#  "'main',",
#  "'reason',",
#  "'story',",
#  "'ties',",
#  "'connections',",
#  "'agent',",
#  "'played',",
#  "'nureyev',",
#  "'pretends',",
#  "'use',",
#  "'elizabeth',",
#  "'bait',",
#  ...]

# %%
stopwords = ['movie','movies' , 'film', 'films', 'scenes', 'actors', 'actor', ' acting', 'role', 'script', 'story', 'director', 'scene', 'plot', 'character', 'characters', 'plays', 'played', 'play', 'audience', 'would', 'think', 'thats', 'people', 'performance', 'part']

words = negative_text_split

output = []


# words = negative_text
for word in list(words):  # iterating on a copy since removing will mess things up
    if word.replace("'", "").replace(",", "") not in stopwords:
        output.append(word)
        
#words = [word for i in words if i not in stopwords]


output
# Out:
# ["['yeah',",
#  "'yeahwho',",
#  "'could',",
#  "'find',",
#  "'fault',",
#  "'implausible',",
#  "'menagerie',",
#  "'models',",
#  "'marxists',",
#  "'even',",
#  "'inept',",
#  "'filmschoolers',",
#  "'could',",
#  "'find',",
#  "'surplus',",
#  "'shortfalls',",
#  "'offer',",
#  "'trite',",
#  "'insight',",
#  "'whats',",
#  "'blatantly',",
#  "'apparent',",
#  "'isthe',",
#  "'seems',",
#  "'never',",
#  "'transcended',",
#  "'firstdraft',",
#  "'stagethe',",
#  "'seem',",
#  "'either',",
#  "'psychotropic',",
#  "'drugs',",
#  "'need',",
#  "'psychotherapeutic',",
#  "'onesand',",
#  "'seems',",
#  "'mind',",
#  "'things',",
#  "'\\x96',",
#  "'perhaps',",
#  "'act',",
#  "'small',",
#  "'completely',",
#  "'forgettable',",
#  "'parthowever',",
#  "'us',",
#  "'challenge',",
#  "'discover',",
#  "'good',",
#  "'points',",
#  "'critical',",
#  "'failures',",
#  "'exposed',",
#  "'everyone',",
#  "'seems',",
#  "'somewhat',",
#  "'vaguely',",
#  "'aware',",
#  "'whats',",
#  "'redeeming',",
#  "'word',",
#  "'nastassjakinski',",
#  "'camera',",
#  "'problems',",
#  "'behind',",
#  "'seem',",
#  "'insignificantcheers',",
#  "'jb',",
#  "'prospect',",
#  "'point',",
#  "'productions',",
#  "'inc',",
#  "'early',",
#  "'80s',",
#  "'seemed',",
#  "'ripe',",
#  "'time',",
#  "'espionagethemed',",
#  "'taken',",
#  "'whole',",
#  "'probably',",
#  "'somewhere',",
#  "'middle',",
#  "'terms',",
#  "'quality',",
#  "'goodness',",
#  "'knows',",
#  "'worse',",
#  "'however',",
#  "'makes',",
#  "'worth',",
#  "'seeing',",
#  "'two',",
#  "'things',",
#  "'european',",
#  "'locales',",
#  "'monochromatic',",
#  "'greys',",
#  "'browns',",
#  "'first',",
#  "'foremost',",
#  "'astonishing',",
#  "'eyeachingly',",
#  "'beautiful',",
#  "'kinski',",
#  "'may',",
#  "'well',",
#  "'ripest',",
#  "'fiercest',",
#  "'raw',",
#  "'captured',",
#  "'surrounds',",
#  "'unfortunately',",
#  "'either',",
#  "'standard',",
#  "'downright',",
#  "'embarassing',",
#  "'wooden',",
#  "'supporting',",
#  "'performances',",
#  "'particularly',",
#  "'nureyev',",
#  "'looks',",
#  "'singularly',",
#  "'uneasy',",
#  "'clodding',",
#  "'ironic',",
#  "'someone',",
#  "'spent',",
#  "'lifetime',",
#  "'praised',",
#  "'graceful',",
#  "'moves',",
#  "'often',",
#  "'senseless',",
#  "'direction',",
#  "'veers',",
#  "'shameful',",
#  "'confused',",
#  "'none',",
#  "'helped',",
#  "'sometimesspastic',",
#  "'editing',",
#  "'yetthere',",
#  "'kinski',",
#  "'breathing',",
#  "'life',",
#  "'dull',",
#  "'affair',",
#  "'spite',",
#  "'wiping',",
#  "'everyone',",
#  "'else',",
#  "'screen',",
#  "'audiences',",
#  "'eyes',",
#  "'minds',",
#  "'force',",
#  "'reckoned',",
#  "'radiating',",
#  "'intriguing',",
#  "'blend',",
#  "'natural',",
#  "'awkwardness',",
#  "'justenough',",
#  "'confidence',",
#  "'essence',",
#  "'100',",
#  "'real',",
#  "'isnt',",
#  "'single',",
#  "'false',",
#  "'moment',",
#  "'delivered',",
#  "'young',",
#  "'woman',",
#  "'falls',",
#  "'world',",
#  "'modeling',",
#  "'espionage',",
#  "'giving',",
#  "'whole',",
#  "'unmistakable',",
#  "'air',",
#  "'whatcouldhavebeen',",
#  "'tenth',",
#  "'provides',",
#  "'still',",
#  "'rate',",
#  "'despite',",
#  "'dated',",
#  "'modernday',",
#  "'classic',",
#  "'whatever',",
#  "'many',",
#  "'many',",
#  "'flaws',",
#  "'worth',",
#  "'seeing',",
#  "'oftensilly',",
#  "'early80s',",
#  "'fashions',",
#  "'time',",
#  "'machine',",
#  "'aforementioned',",
#  "'locales',",
#  "'main',",
#  "'reason',",
#  "'brilliant',",
#  "'moments',",
#  "'amazing',",
#  "'hard',",
#  "'describe',",
#  "'words',",
#  "'occurs',",
#  "'find',",
#  "'strikingkinski',",
#  "'sheer',",
#  "'brilliance',",
#  "'delivers',",
#  "'phenomenal',",
#  "'seduces',",
#  "'camera',",
#  "'without',",
#  "'ego',",
#  "'never',",
#  "'seen',",
#  "'done',",
#  "'another',",
#  "'actress',",
#  "'sense',",
#  "'though',",
#  "'watching',",
#  "'documentarythe',",
#  "'awful',",
#  "'mess',",
#  "'time',",
#  "'found',",
#  "'fascinating',",
#  "'dance',",
#  "'kinski',",
#  "'unfurnished',",
#  "'apartment',",
#  "'strong',",
#  "'sense',",
#  "'individual',",
#  "'void',",
#  "'conformity',",
#  "'life',",
#  "'dances',",
#  "'beat',",
#  "'drumthere',",
#  "'another',",
#  "'kinski',",
#  "'gets',",
#  "'cab',",
#  "'falls',",
#  "'street',",
#  "'gets',",
#  "'runs',",
#  "'away',",
#  "'limp',",
#  "'step',",
#  "'found',",
#  "'intriguing',",
#  "'say',",
#  "'seemed',",
#  "'awkward',",
#  "'awkward',",
#  "'filmi',",
#  "'like',",
#  "'foolishness',",
#  "'attempt',",
#  "'making',",
#  "'world',",
#  "'fashion',",
#  "'terrorism',",
#  "'seem',",
#  "'romantickinski',",
#  "'breaks',",
#  "'barrier',",
#  "'screen',",
#  "'magazine',",
#  "'variety',",
#  "'stated',",
#  "'perfect',",
#  "'description',",
#  "'roger',",
#  "'ebert',",
#  "'offers',",
#  "'excellent',",
#  "'review',",
#  "'highly',",
#  "'agree',",
#  "'itcheck',",
#  "'sometime',",
#  "'see',",
#  "'star',",
#  "'work',",
#  "'like',",
#  "'others',",
#  "'commented',",
#  "'first',",
#  "'watched',",
#  "'20',",
#  "'years',",
#  "'ago',",
#  "'seen',",
#  "'times',",
#  "'since',",
#  "'im',",
#  "'sure',",
#  "'definitely',",
#  "'intriguing',",
#  "'mess',",
#  "'wisconsin',",
#  "'girl',",
#  "'named',",
#  "'elizabeth',",
#  "'carlson',",
#  "'nastassja',",
#  "'kinski',",
#  "'leaves',",
#  "'college',",
#  "'heads',",
#  "'new',",
#  "'york',",
#  "'city',",
#  "'getting',",
#  "'job',",
#  "'waitress',",
#  "'discovered',",
#  "'fashion',",
#  "'agent',",
#  "'makes',",
#  "'successful',",
#  "'modelspoiler',",
#  "'alert',",
#  "'going',",
#  "'notices',",
#  "'strange',",
#  "'man',",
#  "'following',",
#  "'rudolf',",
#  "'nureyev',",
#  "'eventually',",
#  "'confront',",
#  "'learns',",
#  "'name',",
#  "'daniel',",
#  "'jelline',",
#  "'wants',",
#  "'kill',",
#  "'terrorist',",
#  "'engage',",
#  "'romance',",
#  "'follows',",
#  "'paris',",
#  "'gets',",
#  "'upset',",
#  "'discovers',",
#  "'used',",
#  "'try',",
#  "'get',",
#  "'closer',",
#  "'rivas',",
#  "'harvey',",
#  "'keitel',",
#  "'whos',",
#  "'terrorist',",
#  "'plotting',",
#  "'next',",
#  "'act',",
#  "'destruction',",
#  "'elizabeth',",
#  "'notices',",
#  "'woman',",
#  "'new',",
#  "'york',",
#  "'watching',",
#  "'recognizes',",
#  "'one',",
#  "'members',",
#  "'rivas',",
#  "'gang',",
#  "'strike',",
#  "'conversation',",
#  "'results',",
#  "'getting',",
#  "'opportunity',",
#  "'meet',",
#  "'rivas',",
#  "'lets',",
#  "'go',",
#  "'immediately',",
#  "'goes',",
#  "'get',",
#  "'daniel',",
#  "'leads',",
#  "'violent',",
#  "'bloody',",
#  "'conclusionthis',",
#  "'third',",
#  "'james',",
#  "'toback',",
#  "'written',",
#  "'directed',",
#  "'still',",
#  "'riding',",
#  "'critical',",
#  "'praise',",
#  "'first',",
#  "'fingers',",
#  "'seemed',",
#  "'bite',",
#  "'could',",
#  "'chew',",
#  "'first',",
#  "'nobody',",
#  "'believed',",
#  "'kinski',",
#  "'girl',",
#  "'midwest',",
#  "'never',",
#  "'appeared',",
#  "'home',",
#  "'arrived',",
#  "'paris',",
#  "'keitel',",
#  "'woefully',",
#  "'miscast',",
#  "'terrorist',",
#  "'multiple',",
#  "'viewings',",
#  "'never',",
#  "'sure',",
#  "'supposed',",
#  "'parisian',",
#  "'something',",
#  "'else',",
#  "'ive',",
#  "'heard',",
#  "'everyone',",
#  "'describe',",
#  "'nureyevs',",
#  "'wooden',",
#  "'stiff',",
#  "'dark',",
#  "'eyes',",
#  "'always',",
#  "'compared',",
#  "'dracula',",
#  "'every',",
#  "'time',",
#  "'spoke',",
#  "'either',",
#  "'speak',",
#  "'metaphors',",
#  "'recite',",
#  "'something',",
#  "'poetically',",
#  "'always',",
#  "'something',",
#  "'curiosity',",
#  "'reason',",
#  "'get',",
#  "'admit',",
#  "'bad',",
#  "'theres',",
#  "'something',",
#  "'alluring',",
#  "'intriguing',",
#  "'casting',",
#  "'kinski',",
#  "'often',",
#  "'described',",
#  "'force',",
#  "'reckon',",
#  "'one',",
#  "'point',",
#  "'kinski',",
#  "'dance',",
#  "'unique',",
#  "'screen',",
#  "'presence',",
#  "'one',",
#  "'cant',",
#  "'help',",
#  "'absorbed',",
#  "'tobacks',",
#  "'high',",
#  "'aspirations',",
#  "'ambitious',",
#  "'us',",
#  "'commands',",
#  "'sort',",
#  "'attention',",
#  "'many',",
#  "'future',",
#  "'viewers',",
#  "'simply',",
#  "'reject',",
#  "'one',",
#  "'viewing',",
#  "'twice',",
#  "'us',",
#  "'watched',",
#  "'kinski',",
#  "'toback',",
#  "'rise',",
#  "'theyre',",
#  "'abilities',",
#  "'early',",
#  "'80s',",
#  "'clumsy',",
#  "'always',",
#  "'something',",
#  "'curiosity',",
#  "'exposed',",
#  "'one',",
#  "'unusual',",
#  "'different',",
#  "'unpredictable',",
#  "'ever',",
#  "'seen',",
#  "'many',",
#  "'reviews',",
#  "'imdb',",
#  "'fault',",
#  "'incoherent',",
#  "'actually',",
#  "'believe',",
#  "'criticism',",
#  "'unjustified',",
#  "'since',",
#  "'writerdirector',",
#  "'james',",
#  "'toback',",
#  "'really',",
#  "'trying',",
#  "'make',",
#  "'ambitious',",
#  "'theme',",
#  "'western',",
#  "'world',",
#  "'breaking',",
#  "'morally',",
#  "'politically',",
#  "'economically',",
#  "'every',",
#  "'way',",
#  "'toback',",
#  "'playing',",
#  "'professor',",
#  "'picture',",
#  "'even',",
#  "'makes',",
#  "'point',",
#  "'rather',",
#  "'banally',",
#  "'classroom',",
#  "'filled',",
#  "'indifferent',",
#  "'students',",
#  "'pursues',",
#  "'theme',",
#  "'fresh',",
#  "'original',",
#  "'way',",
#  "'exploring',",
#  "'turbulent',",
#  "'life',",
#  "'elizabeth',",
#  "'carlson',",
#  "'brilliantly',",
#  "'german',",
#  "'actress',",
#  "'nastassja',",
#  "'kinski',",
#  "'beginning',",
#  "'shows',",
#  "'terrorist',",
#  "'attack',",
#  "'elizabeth',",
#  "'looking',",
#  "'indifferently',",
#  "'literature',",
#  "'professor',",
#  "'order',",
#  "'begging',",
#  "'question',",
#  "'two',",
#  "'related',",
#  "'course',",
#  "'series',",
#  "'extraordinary',",
#  "'nonetheless',",
#  "'plausible',",
#  "'twists',",
#  "'learn',",
#  "'answer',",
#  "'question',",
#  "'end',",
#  "'shows',",
#  "'elizabeth',",
#  "'gazing',",
#  "'dying',",
#  "'lover',",
#  "'streets',",
#  "'paris',",
#  "'western',",
#  "'world',",
#  "'metaphorical',",
#  "'sense',",
#  "'collapses',",
#  "'around',",
#  "'heraside',",
#  "'mostly',",
#  "'interesting',",
#  "'strength',",
#  "'lies',",
#  "'natassija',",
#  "'kinskis',",
#  "'elizabeth',",
#  "'brilliantly',",
#  "'almost',",
#  "'overlook',",
#  "'moments',",
#  "'delivers',",
#  "'poor',",
#  "'lines',",
#  "'rudolf',",
#  "'nureyevs',",
#  "'enigmatic',",
#  "'violinist',",
#  "'david',",
#  "'jelline',",
#  "'good',",
#  "'still',",
#  "'interesting',",
#  "'watch',",
#  "'without',",
#  "'weaknesses',",
#  "'found',",
#  "'acting',",
#  "'supporting',",
#  "'cast',",
#  "'amateurish',",
#  "'dull',",
#  "'including',",
#  "'tobacks',",
#  "'brief',",
#  "'literature',",
#  "'professor',",
#  "'moreover',",
#  "'exposed',",
#  "'starts',",
#  "'bit',",
#  "'slowly',",
#  "'beginning',",
#  "'picking',",
#  "'tempo',",
#  "'becoming',",
#  "'interesting',",
#  "'yet',",
#  "'enough',",
#  "'unexpected',",
#  "'developments',",
#  "'including',",
#  "'violin',",
#  "'seduction',",
#  "'seen',",
#  "'believed',",
#  "'classical',",
#  "'music',",
#  "'interesting',",
#  "'keep',",
#  "'interested',",
#  "'right',",
#  "'end',",
#  "'exposed',",
#  "'one',",
#  "'stories',",
#  "'take',",
#  "'quite',",
#  "'long',",
#  "'time',",
#  "'finally',",
#  "'get',",
#  "'needs',",
#  "'makes',",
#  "'turns',",
#  "'twists',",
#  "'gets',",
#  "'point',",
#  "'rushes',",
#  "'things',",
#  "'shouldnt',",
#  "'develops',",
#  "'much',",
#  "'one',",
#  "'hides',",
#  "'much',",
#  "'presenting',",
#  "'others',",
#  "'viewed',",
#  "'strange',",
#  "'difficulting',",
#  "'accepting',",
#  "'everything',",
#  "'presented',",
#  "'follow',",
#  "'detail',",
#  "'stardom',",
#  "'elizabeth',",
#  "'nastassja',",
#  "'kinski',",
#  "'young',",
#  "'woman',",
#  "'abandons',",
#  "'studies',",
#  "'goes',",
#  "'new',",
#  "'york',",
#  "'try',",
#  "'make',",
#  "'living',",
#  "'fails',",
#  "'gets',",
#  "'discovered',",
#  "'photographer',",
#  "'ian',",
#  "'mcshane',",
#  "'wholl',",
#  "'make',",
#  "'supermodel',",
#  "'like',",
#  "'barely',",
#  "'girl',",
#  "'could',",
#  "'predict',",
#  "'going',",
#  "'meet',",
#  "'strange',",
#  "'man',",
#  "'rudolf',",
#  "'nureyev',",
#  "'make',",
#  "'life',",
#  "'turn',",
#  "'upside',",
#  "'offer',",
#  "'help',",
#  "'catch',",
#  "'terrorist',",
#  "'harvey',",
#  "'keitel',",
#  "'group',",
#  "'spreads',",
#  "'terror',",
#  "'europe',",
#  "'connection',",
#  "'isnt',",
#  "'worth',",
#  "'mentioning',",
#  "'one',",
#  "'say',",
#  "'doesnt',",
#  "'satisfy',",
#  "'much',",
#  "'theres',",
#  "'something',",
#  "'missing',",
#  "'clear',",
#  "'elizabeth',",
#  "'joining',",
#  "'man',",
#  "'benefit',",
#  "'way',",
#  "'probably',",
#  "'shes',",
#  "'share',",
#  "'something',",
#  "'special',",
#  "'put',",
#  "'aside',",
#  "'logic',",
#  "'great',",
#  "'notion',",
#  "'makes',",
#  "'great',",
#  "'great',",
#  "'exposed',",
#  "'one',",
#  "'thing',",
#  "'fun',",
#  "'watch',",
#  "'glamorous',",
#  "'exciting',",
#  "'little',",
#  "'thrilling',",
#  "'multigenre',",
#  "'piece',",
#  "'knows',",
#  "'sell',",
#  "'beauty',",
#  "'pleasure',",
#  "'joys',",
#  "'highlife',",
#  "'excitement',",
#  "'fashion',",
#  "'world',",
#  "'rare',",
#  "'seen',",
#  "'life',",
#  "'throws',",
#  "'middle',",
#  "'strange',",
#  "'view',",
#  "'current',",
#  "'wave',",
#  "'terrorism',",
#  "'1980s',",
#  "'idealists',",
#  "'fighting',",
#  "'imperialism',",
#  "'yet',",
#  "'wanting',",
#  "'things',",
#  "'keitels',",
#  "'makes',",
#  "'perfectly',",
#  "'clear',",
#  "'things',",
#  "'fights',",
#  "'got',",
#  "'ta',",
#  "'acknowledge',",
#  "'way',",
#  "'james',",
#  "'toback',",
#  "'presents',",
#  "'whole',",
#  "'thing',",
#  "'great',",
#  "'sense',",
#  "'style',",
#  "'paris',",
#  "'fascinating',",
#  "'ones',",
#  "'new',",
#  "'york',",
#  "'much',",
#  "'sensual',",
#  "'provocative',",
#  "'theres',",
#  "'even',",
#  "'bits',",
#  "'good',",
#  "'dialogues',",
#  "'high',",
#  "'points',",
#  "'opening',",
#  "'ending',",
#  "'terrorist',",
#  "'attack',",
#  "'heart',",
#  "'goes',",
#  "'mouth',",
#  "'violin',",
#  "'one',",
#  "'erotic',",
#  "'moments',",
#  "'history',",
#  "'clothes',",
#  "'elizabeth',",
#  "'joining',",
#  "'group',",
#  "'ending',",
#  "'rushed',",
#  "'could',",
#  "'inventive',",
#  "'riskier',",
#  "'dangerous',",
#  "'happened',",
#  "'bombsmost',",
#  "'reviews',",
#  "'states',",
#  "'exposed',",
#  "'mess',",
#  "'wonder',",
#  "'really',",
#  "'watching',",
#  "'maybe',",
#  "'dazzled',",
#  "'kinskis',",
#  "'beauty',",
#  "'got',",
#  "'lost',",
#  "'somewhere',",
#  "'couldnt',",
#  "'keep',",
#  "'going',",
#  "'right',",
#  "'messy',",
#  "'quite',",
#  "'simple',",
#  "'follow',",
#  "'upsets',",
#  "'giant',",
#  "'hole',",
#  "'featured',",
#  "'main',",
#  "'reason',",
#  "'ties',",
#  "'connections',",
#  "'agent',",
#  "'nureyev',",
#  "'pretends',",
#  "'use',",
#  "'elizabeth',",
#  "'bait',",
#  "'attract',",
#  "'terrorists',",
#  "'since',",
#  "'one',",
#  "'members',",
#  "'attracted',",
#  "'photo',",
#  "'session',",
#  "'paris',",
#  "'dont',",
#  "'remember',",
#  "'seeing',",
#  "'partners',",
#  "'photo',",
#  "'shoot',",
#  "'kind',",
#  "'mention',",
#  "'could',",
#  "'one',",
#  "'make',",
#  "'idea',",
#  "'use',",
#  "'favor',",
#  "'thereeverything',",
#  "'might',",
#  "'halfway',",
#  "'underdeveloped',",
#  "'main',",
#  "'attribute',",
#  "'exposed',",
#  "'isnt',",
#  "'kinskis',",
#  "'presence',",
#  "'perfect',",
#  "'vehicle',",
#  "'know',",
#  "'best',",
#  "'explore',",
#  "'grace',",
#  "'beauty',",
#  "'glory',",
#  "'dont',",
#  "'except',",
#  "'level',",
#  "'acting',",
#  "'great',",
#  "'paris',",
#  "'texas',",
#  "'shes',",
#  "'fine',",
#  "'made',",
#  "'desired',",
#  "'admired',",
#  "'cast',",
#  "'members',",
#  "'name',",
#  "'sake',",
#  "'nureyev',",
#  "'completely',",
#  "'wooden',",
#  "'theres',",
#  "'something',",
#  "'makes',",
#  "'good',",
#  "'choice',",
#  "'hated',",
#  "'accent',",
#  "'difficult',",
#  "'hear',",
#  "'times',",
#  "'keitel',",
#  "'good',",
#  "'sinister',",
#  "'create',",
#  "'much',",
#  "'anticipation',",
#  "'disappoints',",
#  "'hes',",
#  ...]

# %%
# # Function to convert   
# def listToString(s):  
#     # initialize an empty string 
#     str1 = " " 
#     # return string   
#     return (str1.join(s)) 
# # Driver code     
# s = words 
# print(listToString(s))  

makeitastring = ''.join(map(str, output))

# %%
# WordCloud for Positive Reviews
wordcloud = WordCloud(width=500, height=500, max_font_size=40, min_font_size=15).generate(makeitastring)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
wordcloud.to_file("Negative_Reviews_New.png")

# %%
stopwords = ['movie','movies' , 'film', 'films', 'scenes', 'actors', 'actor', ' acting', 'role', 'script', 'story', 'director', 'scene', 'plot', 'character', 'characters', 'plays', 'played', 'play', 'audience', 'would', 'think', 'thats', 'people', 'performance', 'part']

words = positive_text_split

output2 = []


# words = negative_text
for word in list(words):  # iterating on a copy since removing will mess things up
    if word.replace("'", "").replace(",", "") not in stopwords:
        output2.append(word)
        
#words = [word for i in words if i not in stopwords]


output2
# Out:
# ["['early',",
#  "'seventies',",
#  "'western',",
#  "'genre',",
#  "'severe',",
#  "'decline',",
#  "'exception',",
#  "'clint',",
#  "'eastwood',",
#  "'bankable',",
#  "'within',",
#  "'genre',",
#  "'could',",
#  "'return',",
#  "'sure',",
#  "'fire',",
#  "'hit',",
#  "'john',",
#  "'wayne',",
#  "'however',",
#  "'made',",
#  "'string',",
#  "'westerns',",
#  "'succession',",
#  "'john',",
#  "'wayne',",
#  "'eager',",
#  "'broaden',",
#  "'horizons',",
#  "'undertake',",
#  "'new',",
#  "'project',",
#  "'project',",
#  "'contemporary',",
#  "'detective',",
#  "'drama',",
#  "'titled',",
#  "'mcqmcq',",
#  "'set',",
#  "'seattle',",
#  "'follows',",
#  "'lon',",
#  "'mcq',",
#  "'duke',",
#  "'pursuit',",
#  "'gangsters',",
#  "'murdered',",
#  "'friend',",
#  "'colleague',",
#  "'stan',",
#  "'boyle',",
#  "'quest',",
#  "'intensifies',",
#  "'mcq',",
#  "'uncovers',",
#  "'motive',",
#  "'behind',",
#  "'friends',",
#  "'killing',",
#  "'uncovers',",
#  "'corruption',",
#  "'stems',",
#  "'right',",
#  "'top',",
#  "'police',",
#  "'hierarchywhile',",
#  "'slammed',",
#  "'critics',",
#  "'anti',",
#  "'wayne',",
#  "'elements',",
#  "'impossible',",
#  "'deny',",
#  "'john',",
#  "'wayne',",
#  "'well',",
#  "'cast',",
#  "'tough',",
#  "'cop',",
#  "'something',",
#  "'outsider',",
#  "'world',",
#  "'changing',",
#  "'values',",
#  "'duke',",
#  "'gives',",
#  "'fine',",
#  "'good',",
#  "'supporting',",
#  "'players',",
#  "'notably',",
#  "'eddie',",
#  "'albert',",
#  "'al',",
#  "'lettieri',",
#  "'colleen',",
#  "'dewhurst',",
#  "'diana',",
#  "'muldaur',",
#  "'wellstaged',",
#  "'action',",
#  "'including',",
#  "'two',",
#  "'highspeed',",
#  "'car',",
#  "'chases',",
#  "'exciting',",
#  "'climatic',",
#  "'shootout',",
#  "'one',",
#  "'notable',",
#  "'somewhat',",
#  "'improbable',",
#  "'action',",
#  "'involves',",
#  "'two',",
#  "'lorries',",
#  "'playing',",
#  "'largescale',",
#  "'version',",
#  "'dodgems',",
#  "'mcqs',",
#  "'car',",
#  "'akin',",
#  "'james',",
#  "'bond',",
#  "'moviethe',",
#  "'delves',",
#  "'several',",
#  "'interesting',",
#  "'areas',",
#  "'including',",
#  "'corruption',",
#  "'family',",
#  "'breakdowns',",
#  "'shadowy',",
#  "'underworld',",
#  "'drugs',",
#  "'one',",
#  "'brilliantly',",
#  "'directed',",
#  "'acted',",
#  "'involves',",
#  "'mcq',",
#  "'exchanging',",
#  "'drugs',",
#  "'vital',",
#  "'information',",
#  "'imminent',",
#  "'drugs',",
#  "'heist',",
#  "'illustrates',",
#  "'complex',",
#  "'drug',",
#  "'underworld',",
#  "'actually',",
#  "'chemistry',",
#  "'mcq',",
#  "'myra',",
#  "'evidentthe',",
#  "'overall',",
#  "'tone',",
#  "'notably',",
#  "'grim',",
#  "'gritty',",
#  "'benefited',",
#  "'larger',",
#  "'budget',",
#  "'tighter',",
#  "'direction',",
#  "'greater',",
#  "'development',",
#  "'nevertheless',",
#  "'mcq',",
#  "'undeniable',",
#  "'hit',",
#  "'box',",
#  "'office',",
#  "'worthy',",
#  "'entry',",
#  "'john',",
#  "'waynes',",
#  "'impressive',",
#  "'portfolio',",
#  "'whenever',",
#  "'watch',",
#  "'mcq',",
#  "'two',",
#  "'things',",
#  "'always',",
#  "'stand',",
#  "'first',",
#  "'john',",
#  "'wayne',",
#  "'always',",
#  "'gets',",
#  "'criticized',",
#  "'copying',",
#  "'clint',",
#  "'eastwoods',",
#  "'dirty',",
#  "'harry',",
#  "'cop',",
#  "'mcq',",
#  "'brannigan',",
#  "'always',",
#  "'commonly',",
#  "'said',",
#  "'duke',",
#  "'old',",
#  "'cop',",
#  "'ive',",
#  "'always',",
#  "'disagreed',",
#  "'line',",
#  "'thinking',",
#  "'remember',",
#  "'dean',",
#  "'martin',",
#  "'matt',",
#  "'helm',",
#  "'series',",
#  "'going',",
#  "'columbia',",
#  "'late',",
#  "'60s',",
#  "'frank',",
#  "'sinatra',",
#  "'tony',",
#  "'rome',",
#  "'series',",
#  "'fox',",
#  "'time',",
#  "'later',",
#  "'robert',",
#  "'mitchum',",
#  "'chandlers',",
#  "'philip',",
#  "'marlowe',",
#  "'two',",
#  "'guys',",
#  "'definitely',",
#  "'dukes',",
#  "'age',",
#  "'bracket',",
#  "'duke',",
#  "'mind',",
#  "'decided',",
#  "'make',",
#  "'detective',",
#  "'eastwoodthe',",
#  "'second',",
#  "'thing',",
#  "'ive',",
#  "'always',",
#  "'noticed',",
#  "'one',",
#  "'mentioned',",
#  "'far',",
#  "'im',",
#  "'bit',",
#  "'surprised',",
#  "'nobody',",
#  "'mentioned',",
#  "'even',",
#  "'count',",
#  "'like',",
#  "'long',",
#  "'voyage',",
#  "'home',",
#  "'cowboys',",
#  "'mcq',",
#  "'may',",
#  "'well',",
#  "'depressing',",
#  "'john',",
#  "'wayne',",
#  "'ever',",
#  "'made',",
#  "'end',",
#  "'lon',",
#  "'mcqs',",
#  "'best',",
#  "'friend',",
#  "'partner',",
#  "'william',",
#  "'bryant',",
#  "'revealed',",
#  "'drug',",
#  "'dealer',",
#  "'league',",
#  "'many',",
#  "'crooked',",
#  "'city',",
#  "'officials',",
#  "'friends',",
#  "'wife',",
#  "'diana',",
#  "'muldaur',",
#  "'revealed',",
#  "'scheme',",
#  "'mcqs',",
#  "'wife',",
#  "'julie',",
#  "'adams',",
#  "'gone',",
#  "'womens',",
#  "'lib',",
#  "'movement',",
#  "'divorced',",
#  "'married',",
#  "'another',",
#  "'man',",
#  "'daughter',",
#  "'kim',",
#  "'sanford',",
#  "'rather',",
#  "'hang',",
#  "'friends',",
#  "'spend',",
#  "'time',",
#  "'father',",
#  "'mcqs',",
#  "'socalled',",
#  "'friends',",
#  "'kosterman',",
#  "'eddie',",
#  "'albert',",
#  "'jc',",
#  "'jim',",
#  "'watkins',",
#  "'using',",
#  "'personal',",
#  "'friendship',",
#  "'spy',",
#  "'intent',",
#  "'arresting',",
#  "'drug',",
#  "'rings',",
#  "'crimesin',",
#  "'words',",
#  "'everyone',",
#  "'everything',",
#  "'complete',",
#  "'total',",
#  "'sob',",
#  "'except',",
#  "'lon',",
#  "'mcq',",
#  "'stands',",
#  "'alone',",
#  "'corruption',",
#  "'moral',",
#  "'relevancy',",
#  "'colleagues',",
#  "'friends',",
#  "'around',",
#  "'straight',",
#  "'narrow',",
#  "'way',",
#  "'usually',",
#  "'hard',",
#  "'lon',",
#  "'mcq',",
#  "'certainly',",
#  "'share',",
#  "'troubles',",
#  "'professional',",
#  "'personal',",
#  "'throughout',",
#  "'filmthe',",
#  "'two',",
#  "'really',",
#  "'stand',",
#  "'first',",
#  "'foremost',",
#  "'dukes',",
#  "'encounter',",
#  "'druggie',",
#  "'lowlife',",
#  "'colleen',",
#  "'dewhurst',",
#  "'trying',",
#  "'get',",
#  "'information',",
#  "'duke',",
#  "'usual',",
#  "'professional',",
#  "'self',",
#  "'colleen',",
#  "'dewhurst',",
#  "'really',",
#  "'shines',",
#  "'anything',",
#  "'batjac',",
#  "'probably',",
#  "'gotten',",
#  "'best',",
#  "'supporting',",
#  "'actress',",
#  "'oscar',",
#  "'nomination',",
#  "'shes',",
#  "'really',",
#  "'great',",
#  "'duke',",
#  "'proves',",
#  "'generous',",
#  "'john',",
#  "'ford',",
#  "'taught',",
#  "'set',",
#  "'stagecoach',",
#  "'good',",
#  "'supporting',",
#  "'performances',",
#  "'make',",
#  "'star',",
#  "'look',",
#  "'even',",
#  "'better',",
#  "'lesson',",
#  "'took',",
#  "'heart',",
#  "'costars',",
#  "'throughout',",
#  "'long',",
#  "'career',",
#  "'always',",
#  "'said',",
#  "'never',",
#  "'counted',",
#  "'minutes',",
#  "'worried',",
#  "'upstaged',",
#  "'costars',",
#  "'maureen',",
#  "'ohara',",
#  "'said',",
#  "'autobiography',",
#  "'view',",
#  "'always',",
#  "'wanted',",
#  "'steal',",
#  "'go',",
#  "'ahead',",
#  "'try',",
#  "'succeeded',",
#  "'power',",
#  "'underplays',",
#  "'dewhurst',",
#  "'magnificently',",
#  "'allowing',",
#  "'deliver',",
#  "'acting',",
#  "'goodsthe',",
#  "'second',",
#  "'occurs',",
#  "'wayne',",
#  "'confronts',",
#  "'diana',",
#  "'muldaur',",
#  "'car',",
#  "'drive',",
#  "'town',",
#  "'meet',",
#  "'lover',",
#  "'clu',",
#  "'gulager',",
#  "'skip',",
#  "'town',",
#  "'muldaur',",
#  "'driving',",
#  "'car',",
#  "'wayne',",
#  "'sitting',",
#  "'passengers',",
#  "'seat',",
#  "'confronts',",
#  "'husbands',",
#  "'involvement',",
#  "'drug',",
#  "'ring',",
#  "'finds',",
#  "'drugs',",
#  "'hidden',",
#  "'suitcase',",
#  "'back',",
#  "'seat',",
#  "'car',",
#  "'becomes',",
#  "'angry',",
#  "'goes',",
#  "'completely',",
#  "'postmodern',",
#  "'morally',",
#  "'relativistic',",
#  "'speech',",
#  "'trying',",
#  "'justify',",
#  "'actions',",
#  "'dukes',",
#  "'facial',",
#  "'expressions',",
#  "'angry',",
#  "'diatribe',",
#  "'worth',",
#  "'millions',",
#  "'hurt',",
#  "'pain',",
#  "'frustration',",
#  "'disappointment',",
#  "'anguish',",
#  "'closeup',",
#  "'stuff',",
#  "'aspiring',",
#  "'kill',",
#  "'comparison',",
#  "'seem',",
#  "'love',",
#  "'compare',",
#  "'dukes',",
#  "'cop',",
#  "'eastwoods',",
#  "'though',",
#  "'said',",
#  "'dont',",
#  "'know',",
#  "'way',",
#  "'world',",
#  "'eastwood',",
#  "'point',",
#  "'career',",
#  "'could',",
#  "'anywhere',",
#  "'nearly',",
#  "'effectively',",
#  "'duke',",
#  "'folks',",
#  "'say',",
#  "'duke',",
#  "'couldnt',",
#  "'act',",
#  "'proved',",
#  "'wrong',",
#  "'country',",
#  "'mileas',",
#  "'said',",
#  "'probably',",
#  "'depressing',",
#  "'dukes',",
#  "'filmography',",
#  "'remember',",
#  "'first',",
#  "'time',",
#  "'watched',",
#  "'dont',",
#  "'ever',",
#  "'remember',",
#  "'feeling',",
#  "'watching',",
#  "'duke',",
#  "'interestingly',",
#  "'enough',",
#  "'mentioned',",
#  "'frank',",
#  "'sinatra',",
#  "'earlier',",
#  "'review',",
#  "'also',",
#  "'ran',",
#  "'similar',",
#  "'problem',",
#  "'earlier',",
#  "'career',",
#  "'1967',",
#  "'made',",
#  "'tony',",
#  "'rome',",
#  "'lighthearted',",
#  "'rat',",
#  "'pack',",
#  "'detective',",
#  "'romp',",
#  "'hit',",
#  "'followed',",
#  "'next',",
#  "'year',",
#  "'detective',",
#  "'serious',",
#  "'drama',",
#  "'dealing',",
#  "'political',",
#  "'corruption',",
#  "'new',",
#  "'york',",
#  "'city',",
#  "'police',",
#  "'department',",
#  "'like',",
#  "'dukes',",
#  "'serious',",
#  "'flopped',",
#  "'sinatra',",
#  "'went',",
#  "'back',",
#  "'playing',",
#  "'tony',",
#  "'rome',",
#  "'lady',",
#  "'cement',",
#  "'well',",
#  "'duke',",
#  "'must',",
#  "'taken',",
#  "'cue',",
#  "'sinatra',",
#  "'next',",
#  "'year',",
#  "'starred',",
#  "'brannigan',",
#  "'another',",
#  "'detective',",
#  "'much',",
#  "'lighthearted',",
#  "'tongueincheek',",
#  "'toneonce',",
#  "'give',",
#  "'credit',",
#  "'duke',",
#  "'trying',",
#  "'something',",
#  "'different',",
#  "'late',",
#  "'career',",
#  "'really',",
#  "'hadnt',",
#  "'done',",
#  "'anything',",
#  "'like',",
#  "'since',",
#  "'big',",
#  "'jim',",
#  "'mclain',",
#  "'1952',",
#  "'unfortunately',",
#  "'much',",
#  "'downer',",
#  "'fans',",
#  "'accept',",
#  "'thankfully',",
#  "'learned',",
#  "'lesson',",
#  "'next',",
#  "'year',",
#  "'come',",
#  "'brannigan',",
#  "'took',",
#  "'far',",
#  "'less',",
#  "'seriously',",
#  "'mcq',",
#  "'hand',",
#  "'apologize',",
#  "'grammar',",
#  "'errors',",
#  "'english',",
#  "'native',",
#  "'language',",
#  "'fr',",
#  "'bullit',",
#  "'maybe',",
#  "'enjoyable',",
#  "'mr',",
#  "'wayne',",
#  "'communicate',",
#  "'street',",
#  "'lingo',",
#  "'well',",
#  "'less',",
#  "'stiff',",
#  "'mr',",
#  "'mcqueenim',",
#  "'actually',",
#  "'like',",
#  "'purchase',",
#  "'music',",
#  "'score',",
#  "'commercially',",
#  "'availablei',",
#  "'dont',",
#  "'understand',",
#  "'elmer',",
#  "'bernstein',",
#  "'included',",
#  "'music',",
#  "'repertoirei',",
#  "'thought',",
#  "'cast',",
#  "'superb',",
#  "'great',",
#  "'line',",
#  "'snitch',",
#  "'said',",
#  "'youre',",
#  "'badge',",
#  "'anymore',",
#  "'ya',",
#  "'gon',",
#  "'na',",
#  "'go',",
#  "'fist',",
#  "'city',",
#  "'car',",
#  "'chase',",
#  "'equal',",
#  "'better',",
#  "'bullits',",
#  "'chase',",
#  "'hopefully',",
#  "'near',",
#  "'future',",
#  "'rereleased',",
#  "'hid',",
#  "'get',",
#  "'enjoy',",
#  "'lived',",
#  "'seattle',",
#  "'early',",
#  "'90s',",
#  "'gather',",
#  "'shot',",
#  "'darn',",
#  "'right',",
#  "'one',",
#  "'john',",
#  "'waynes',",
#  "'appreciated',",
#  "'underlooked',",
#  "'pieces',",
#  "'mcq',",
#  "'one',",
#  "'john',",
#  "'waynes',",
#  "'efforts',",
#  "'move',",
#  "'new',",
#  "'era',",
#  "'mcq',",
#  "'best',",
#  "'waynes',",
#  "'wasnt',",
#  "'worst',",
#  "'old',",
#  "'friend',",
#  "'longer',",
#  "'around',",
#  "'said',",
#  "'bad',",
#  "'john',",
#  "'wayne',",
#  "'turning',",
#  "'50',",
#  "'remember',",
#  "'john',",
#  "'wayne',",
#  "'youth',",
#  "'wayne',",
#  "'always',",
#  "'tops',",
#  "'list',",
#  "'mcq',",
#  "'classic',",
#  "'wayne',",
#  "'new',",
#  "'era',",
#  "'70s',",
#  "'time',",
#  "'men',",
#  "'starting',",
#  "'become',",
#  "'different',",
#  "'like',",
#  "'men',",
#  "'youth',",
#  "'wayne',",
#  "'kept',",
#  "'macho',",
#  "'image',",
#  "'going',",
#  "'another',",
#  "'post',",
#  "'comment',",
#  "'made',",
#  "'wayne',",
#  "'used',",
#  "'big',",
#  "'weapons',",
#  "'foil',",
#  "'bad',",
#  "'guys',",
#  "'long',",
#  "'rambo',",
#  "'exactly',",
#  "'right',",
#  "'great',",
#  "'sit',",
#  "'watch',",
#  "'action',",
#  "'many',",
#  "'great',",
#  "'starts',",
#  "'past',",
#  "'wayne',",
#  "'eddie',",
#  "'albert',",
#  "'diana',",
#  "'muldaur',",
#  "'colleen',",
#  "'dewhurst',",
#  "'clu',",
#  "'gulager',",
#  "'young',",
#  "'roger',",
#  "'e',",
#  "'mosley',",
#  "'another',",
#  "'thing',",
#  "'interest',",
#  "'called',",
#  "'experts',",
#  "'watch',",
#  "'dont',",
#  "'understand',",
#  "'one',",
#  "'thing',",
#  "'comment',",
#  "'one',",
#  "'mcqs',",
#  "'car',",
#  "'trans',",
#  "'amc',",
#  "'hornet',",
#  "'referred',",
#  "'green',",
#  "'hornet',",
#  "'reference',",
#  "'tv',",
#  "'show',",
#  "'green',",
#  "'hornet',",
#  "'nickname',",
#  "'car',",
#  "'made',",
#  "'model',",
#  "'car',",
#  "'trans',",
#  "'color',",
#  "'green',",
#  "'hornets',",
#  "'car',",
#  "'good',",
#  "'john',",
#  "'wayne',",
#  "'good',",
#  "'music',",
#  "'good',",
#  "'car',",
#  "'chases',",
#  "'good',",
#  "'line',",
#  "'good',",
#  "'sit',",
#  "'watch',",
#  "'rainy',",
#  "'afternoon',",
#  "'enjoy',",
#  "'nice',",
#  "'chance',",
#  "'relive',",
#  "'moments',",
#  "'youth',",
#  "'see',",
#  "'duke',",
#  "'action',",
#  "'enjoy',",
#  "'fun',",
#  "'purpose',",
#  "'saw',",
#  "'mcq',",
#  "'first',",
#  "'time',",
#  "'still',",
#  "'dont',",
#  "'understand',",
#  "'harsh',",
#  "'criticism',",
#  "'comes',",
#  "'john',",
#  "'wayne',",
#  "'incredible',",
#  "'comes',",
#  "'ok',",
#  "'effort',",
#  "'looked',",
#  "'crap',",
#  "'ill',",
#  "'admit',",
#  "'academy',",
#  "'award',",
#  "'winner',",
#  "'really',",
#  "'quite',",
#  "'enjoyable',",
#  "'liked',",
#  "'seeing',",
#  "'wayne',",
#  "'something',",
#  "'different',",
#  "'actually',",
#  "'decent',",
#  "'job',",
#  "'tough',",
#  "'cop',",
#  "'went',",
#  "'drugs',",
#  "'corruption',",
#  "'contrast',",
#  "'reviews',",
#  "'ive',",
#  "'read',",
#  "'really',",
#  "'dont',",
#  "'see',",
#  "'much',",
#  "'sameness',",
#  "'time',",
#  "'eg',",
#  "'dirty',",
#  "'harry',",
#  "'dealt',",
#  "'issues',",
#  "'fine',",
#  "'supporting',",
#  "'cast',",
#  "'far',",
#  "'actioners',",
#  "'go',",
#  "'one',",
#  "'holds',",
#  "'turns',",
#  "'pretty',",
#  "'fun',",
#  "'duker',",
#  "'happy',",
#  "'id',",
#  "'particularly',",
#  "'busy',",
#  "'week',",
#  "'decided',",
#  "'vegout',",
#  "'early',",
#  "'friday',",
#  "'afternoon',",
#  "'result',",
#  "'noticed',",
#  "'run',",
#  "'amc',",
#  "'time',",
#  "'normally',",
#  "'wouldnt',",
#  "'watchedfor',",
#  "'reason',",
#  "'one',",
#  "'dukes',",
#  "'id',",
#  "'missed',",
#  "'earlier',",
#  "'never',",
#  "'taped',",
#  "'rented',",
#  "'also',",
#  "'reminded',",
#  "'infrequently',",
#  "'one',",
#  "'saw',",
#  "'onscreen',",
#  "'contemporary',",
#  "'civilian',",
#  "'attireone',",
#  "'later',",
#  "'many',",
#  "'years',",
#  "'illness',",
#  "'death',",
#  "'seemed',",
#  "'surprisingly',",
#  "'spry',",
#  "'energetic',",
#  "'age',",
#  ...]

# %%
makeitastring = ''.join(map(str, output2))

# %%
# WordCloud for Positive Reviews
wordcloud = WordCloud(width=500, height=500, max_font_size=40, min_font_size=15).generate(makeitastring)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
wordcloud.to_file("Positive_Reviews_New.png")
